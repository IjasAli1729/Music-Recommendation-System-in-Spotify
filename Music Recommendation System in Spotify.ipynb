# %%
import pandas as pd

# %%
Data = pd.read_csv(r"C:\Users\Ijas Ali.Machingal\Downloads\Music Recommendation System using Spotify New Dataset.csv")

Data
# Out:
#         valence  year  acousticness  \
# 0        0.0594  1921       0.98200
# 1        0.9630  1921       0.73200
# 2        0.0394  1921       0.96100
# 3        0.1650  1921       0.96700
# 4        0.2530  1921       0.95700
# ...         ...   ...           ...
# 170648   0.6080  2020       0.08460
# 170649   0.7340  2020       0.20600
# 170650   0.6370  2020       0.10100
# 170651   0.1950  2020       0.00998
# 170652   0.6420  2020       0.13200
#
#                                                   artists  danceability  \
# 0       ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                          ['Dennis Day']         0.819
# 2       ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                        ['Frank Parker']         0.275
# 4                                          ['Phil Regan']         0.418
# ...                                                   ...           ...
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170653 entries, 0 to 170652
# Data columns (total 31 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   valence                                 170653 non-null  float64
#  1   year                                    170653 non-null  int64
#  2   acousticness                            170653 non-null  float64
#  3   artists                                 170653 non-null  object
#  4   danceability                            170653 non-null  float64
#  5   duration_ms                             170653 non-null  int64
#  6   energy                                  170653 non-null  float64
#  7   explicit                                170653 non-null  int64
#  8   id                                      170653 non-null  object
#  9   instrumentalness                        170653 non-null  float64
# ...

# %%
Data = Data.drop(['artists','id','name','release_date'], axis = 1)

# %%
Data.describe()
# Out:
#              valence           year   acousticness   danceability  \
# count  170653.000000  170653.000000  170653.000000  170653.000000
# mean        0.528587    1976.787241       0.502115       0.537396
# std         0.263171      25.917853       0.376032       0.176138
# min         0.000000    1921.000000       0.000000       0.000000
# 25%         0.317000    1956.000000       0.102000       0.415000
# 50%         0.540000    1977.000000       0.516000       0.548000
# 75%         0.747000    1999.000000       0.893000       0.668000
# max         1.000000    2020.000000       0.996000       0.988000
#
#         duration_ms         energy       explicit  instrumentalness  \
# count  1.706530e+05  170653.000000  170653.000000     170653.000000
# mean   2.309483e+05       0.482389       0.084575          0.167010
# std    1.261184e+05       0.267646       0.278249          0.313475
# min    5.108000e+03       0.000000       0.000000          0.000000
# ...

# %%
Data.isna().sum()
# Out:
# valence                                      0
# year                                         0
# acousticness                                 0
# danceability                                 0
# duration_ms                                  0
# energy                                       0
# explicit                                     0
# instrumentalness                             0
# key                                          0
# liveness                                     0
# loudness                                     0
# mode                                         0
# popularity                                   0
# speechiness                                  0
# tempo                                        0
# duration_min                                 0
# type_of_song_by_valence                      0
# type_of_song_by_acousticness                 0
# type_of_song_by_danceability                 0
# Energy_Level_of_the_Song                     0
# ...

# %%
Data = Data.dropna()

# %%
Data.isna().sum()
# Out:
# valence                                   0
# year                                      0
# acousticness                              0
# danceability                              0
# duration_ms                               0
# energy                                    0
# explicit                                  0
# instrumentalness                          0
# key                                       0
# liveness                                  0
# loudness                                  0
# mode                                      0
# popularity                                0
# speechiness                               0
# tempo                                     0
# duration_min                              0
# type_of_song_by_valence                   0
# type_of_song_by_acousticness              0
# type_of_song_by_danceability              0
# Energy_Level_of_the_Song                  0
# type_of_song_by_instrumentalness          0
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165235 entries, 0 to 170652
# Data columns (total 27 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   valence                                 165235 non-null  float64
#  1   year                                    165235 non-null  int64
#  2   acousticness                            165235 non-null  float64
#  3   danceability                            165235 non-null  float64
#  4   duration_ms                             165235 non-null  int64
#  5   energy                                  165235 non-null  float64
#  6   explicit                                165235 non-null  int64
#  7   instrumentalness                        165235 non-null  float64
#  8   key                                     165235 non-null  int64
#  9   liveness                                165235 non-null  float64
# ...

# %% [markdown]
# ## LABEL ENCODER

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
Data['type_of_song_by_valence'] = encoder.fit_transform(Data['type_of_song_by_valence'])
Data['type_of_song_by_acousticness'] = encoder.fit_transform(Data['type_of_song_by_acousticness'])
Data['type_of_song_by_danceability'] = encoder.fit_transform(Data['type_of_song_by_danceability'])
Data['Energy_Level_of_the_Song'] = encoder.fit_transform(Data['Energy_Level_of_the_Song'])
Data['type_of_song_by_instrumentalness'] = encoder.fit_transform(Data['type_of_song_by_instrumentalness'])
Data['type_of_song_by_liveness'] = encoder.fit_transform(Data['type_of_song_by_liveness'])
Data['type_of_song_by_loudness(dB)'] = encoder.fit_transform(Data['type_of_song_by_loudness(dB)'])
Data['type_of_song_by_mode'] = encoder.fit_transform(Data['type_of_song_by_mode'])
Data['type_of_popularity'] = encoder.fit_transform(Data['type_of_popularity'])
Data['type_of_song_by_speechiness'] = encoder.fit_transform(Data['type_of_song_by_speechiness'])
Data['type_of_tempo_in_Beats_Per_Minute(BPM)'] = encoder.fit_transform(Data['type_of_tempo_in_Beats_Per_Minute(BPM)'])

# %%
Data
# Out:
#         valence  year  acousticness  danceability  duration_ms  energy  \
# 0        0.0594  1921       0.98200         0.279       831667   0.211
# 1        0.9630  1921       0.73200         0.819       180533   0.341
# 2        0.0394  1921       0.96100         0.328       500062   0.166
# 3        0.1650  1921       0.96700         0.275       210000   0.309
# 4        0.2530  1921       0.95700         0.418       166693   0.193
# ...         ...   ...           ...           ...          ...     ...
# 170648   0.6080  2020       0.08460         0.786       301714   0.808
# 170649   0.7340  2020       0.20600         0.717       150654   0.753
# 170650   0.6370  2020       0.10100         0.634       211280   0.858
# 170651   0.1950  2020       0.00998         0.671       337147   0.623
# 170652   0.6420  2020       0.13200         0.856       189507   0.721
#
#         explicit  instrumentalness  key  liveness  ...  \
# 0              0          0.878000   10    0.6650  ...
# ...

# %% [markdown]
# ## CORRELATION

# %%
Data.corr()
# Out:
#                                          valence      year  acousticness  \
# valence                                 1.000000 -0.024818     -0.191125
# year                                   -0.024818  1.000000     -0.614513
# acousticness                           -0.191125 -0.614513      1.000000
# danceability                            0.569601  0.196990     -0.280572
# duration_ms                            -0.192326  0.078177     -0.075424
# energy                                  0.359547  0.531927     -0.750027
# explicit                               -0.016160  0.221174     -0.246924
# instrumentalness                       -0.200498 -0.271655      0.330935
# key                                     0.027593  0.007849     -0.021641
# liveness                                0.006116 -0.057718     -0.024082
# loudness                                0.315170  0.490174     -0.564149
# mode                                    0.011730 -0.032681      0.047462
# ...

# %%
data = Data.drop(['type_of_song_by_mode'],axis = 'columns')
data
# Out:
#         valence  year  acousticness  danceability  duration_ms  energy  \
# 0        0.0594  1921       0.98200         0.279       831667   0.211
# 1        0.9630  1921       0.73200         0.819       180533   0.341
# 2        0.0394  1921       0.96100         0.328       500062   0.166
# 3        0.1650  1921       0.96700         0.275       210000   0.309
# 4        0.2530  1921       0.95700         0.418       166693   0.193
# ...         ...   ...           ...           ...          ...     ...
# 170648   0.6080  2020       0.08460         0.786       301714   0.808
# 170649   0.7340  2020       0.20600         0.717       150654   0.753
# 170650   0.6370  2020       0.10100         0.634       211280   0.858
# 170651   0.1950  2020       0.00998         0.671       337147   0.623
# 170652   0.6420  2020       0.13200         0.856       189507   0.721
#
#         explicit  instrumentalness  key  liveness  ...  \
# 0              0          0.878000   10    0.6650  ...
# ...

# %%
data1 = Data['type_of_song_by_mode']
data1
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 170648    0
# 170649    0
# 170650    1
# 170651    0
# 170652    0
# Name: type_of_song_by_mode, Length: 165235, dtype: int64

# %%
data
# Out:
#         valence  year  acousticness  danceability  duration_ms  energy  \
# 0        0.0594  1921       0.98200         0.279       831667   0.211
# 1        0.9630  1921       0.73200         0.819       180533   0.341
# 2        0.0394  1921       0.96100         0.328       500062   0.166
# 3        0.1650  1921       0.96700         0.275       210000   0.309
# 4        0.2530  1921       0.95700         0.418       166693   0.193
# ...         ...   ...           ...           ...          ...     ...
# 170648   0.6080  2020       0.08460         0.786       301714   0.808
# 170649   0.7340  2020       0.20600         0.717       150654   0.753
# 170650   0.6370  2020       0.10100         0.634       211280   0.858
# 170651   0.1950  2020       0.00998         0.671       337147   0.623
# 170652   0.6420  2020       0.13200         0.856       189507   0.721
#
#         explicit  instrumentalness  key  liveness  ...  \
# 0              0          0.878000   10    0.6650  ...
# ...

# %% [markdown]
# ## TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(data,data1, test_size=0.2, random_state=42)
X_train,X_test,y_train,y_test
# Out:
# (        valence  year  acousticness  danceability  duration_ms  energy  \
#  101360    0.571  1983      0.157000         0.568       220000  0.8610
#  122297    0.495  2007      0.064000         0.535       260053  0.8070
#  46221     0.395  1965      0.980000         0.557       185560  0.0741
#  147369    0.335  1978      0.769000         0.638       433720  0.2990
#  134621    0.906  1989      0.349000         0.659       173773  0.8510
#  ...         ...   ...           ...           ...          ...     ...
#  123797    0.934  2015      0.396000         0.652       284653  0.8910
#  107076    0.863  2012      0.503000         0.702       200013  0.7150
#  136192    0.166  1997      0.000629         0.559       163107  0.8000
#  151651    0.748  2000      0.234000         0.896       225000  0.8540
#  125923    0.685  1945      0.113000         0.704        95800  0.1800
#
#          explicit  instrumentalness  key  liveness  ...  \
# ...

# %% [markdown]
# ## LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
model1 = LogisticRegression()
model1.fit(X_train,y_train)
# Out:
# C:\Users\Ijas Ali.Machingal\anaconda3\envs\tensernew\Lib\site-packages\sklearn\linear_model\_logistic.py:470: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model1.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
model1.score(X_test,y_test)
# Out:
# 0.7379187218204376

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC

# %%
model2 = SVC(h)
model2.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 model2 = SVC(h)
#       2 model2.fit(X_train,y_train)
#
# NameError: name 'h' is not defined

# %%
model2.predict(X_test)

# %%
model2.score(X_test,y_test)

# %% [markdown]
# ### KERNAL

# %% [markdown]
# POLY

# %%
model3 = SVC(kernel = 'poly')
model3.fit(X_train, y_train)

# %%
model3.predict(X_test)

# %%
model3.score(X_test,y_test)

# %% [markdown]
# RBF

# %%
model4 = SVC(kernel='rbf')
model4.fit(X_train,y_train)

# %%
model4.predict(X_test)

# %%
model4.score(X_test, y_test)

# %% [markdown]
# ### DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model5 = DecisionTreeClassifier()
model5.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model5.predict(X_test)
# Out:
# array([0, 0, 1, ..., 1, 1, 0])

# %%
model5.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# ### RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model6 = RandomForestClassifier()
model6.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model6.predict(X_test)
# Out:
# array([0, 0, 1, ..., 1, 1, 0])

# %%
model6.score(X_test,y_test)
# Out:
# 1.0

# %%
data.columns
# Out:
# Index(['valence', 'year', 'acousticness', 'danceability', 'duration_ms',
#        'energy', 'explicit', 'instrumentalness', 'key', 'liveness', 'loudness',
#        'mode', 'popularity', 'speechiness', 'tempo', 'duration_min',
#        'type_of_song_by_valence', 'type_of_song_by_acousticness',
#        'type_of_song_by_danceability', 'Energy_Level_of_the_Song',
#        'type_of_song_by_instrumentalness', 'type_of_song_by_liveness',
#        'type_of_song_by_loudness(dB)', 'type_of_popularity',
#        'type_of_song_by_speechiness',
#        'type_of_tempo_in_Beats_Per_Minute(BPM)'],
#       dtype='object')

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# SCALING

# %%
data_copy = data.copy()
data_copy.isna().sum()
# Out:
# valence                                   0
# year                                      0
# acousticness                              0
# danceability                              0
# duration_ms                               0
# energy                                    0
# explicit                                  0
# instrumentalness                          0
# key                                       0
# liveness                                  0
# loudness                                  0
# mode                                      0
# popularity                                0
# speechiness                               0
# tempo                                     0
# duration_min                              0
# type_of_song_by_valence                   0
# type_of_song_by_acousticness              0
# type_of_song_by_danceability              0
# Energy_Level_of_the_Song                  0
# type_of_song_by_instrumentalness          0
# ...

# %%
data_copy1 = data1.copy()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data_copy = pd.DataFrame(scaler.fit_transform(data_copy),columns = data.columns)
data_copy
# Out:
#          valence      year  acousticness  danceability  duration_ms    energy  \
# 0      -1.777662 -2.146570      1.271249     -1.496635     4.739915 -1.007538
# 1       1.660343 -2.146570      0.606472      1.584161    -0.404386 -0.521325
# 2      -1.853757 -2.146570      1.215408     -1.217082     2.120061 -1.175842
# 3      -1.375876 -2.146570      1.231363     -1.519456    -0.171582 -0.641008
# 4      -1.041055 -2.146570      1.204772     -0.703616    -0.513730 -1.074859
# ...          ...       ...           ...           ...          ...       ...
# 165230  0.309644  1.669602     -1.115035      1.395890     0.553007  1.225301
# 165231  0.789047  1.669602     -0.792220      1.002233    -0.640446  1.019596
# 165232  0.419983  1.669602     -1.071426      0.528703    -0.161469  1.412306
# 165233 -1.261733  1.669602     -1.313458      0.739795     0.832947  0.533383
# 165234  0.439007  1.669602     -0.988994      1.795253    -0.333487  0.899912
#
# ...

# %%
xtrain,xtest,ytrain,ytest = train_test_split(data_copy,data_copy1, test_size=0.2, random_state= 42)

# %%
knn = KNeighborsClassifier(n_neighbors=4)
knn.fit(xtrain,ytrain)
knn.score(xtest,ytest)
# Out:
# 0.9960964686658396

# %% [markdown]
# ACCURACY RATE TABLE

# %%
accuracy_rate = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(xtrain,ytrain)
    score = knn.score(xtest,ytest)
    accuracy_rate.append(score)

# %%
accuracy_rate
# Out:
# [0.9963990679940691,
#  0.9940085333010561,
#  0.9974884255756952,
#  0.9960964686658396,
#  0.9980936242321542,
#  0.9965201077253608,
#  0.9980331043665083,
#  0.9967924471207674,
#  0.998214663963446,
#  0.9971858262474658,
#  0.9980633642993313,
#  0.9968832269192363,
#  0.9980028444336854,
#  0.9973068659787575,
#  0.998214663963446,
#  0.9972766060459346,
#  0.9980028444336854,
#  0.9971555663146427,
#  0.9979725845008625,
#  0.9970950464489969,
#  0.9977607649711018,
#  0.9970647865161739,
#  0.997609465306987,
#  0.9971253063818198,
#  0.9975186855085182,
#  0.9970950464489969,
#  0.9974884255756952,
#  0.9970950464489969,
#  0.9973371259115805,
#  0.9969740067177051,
#  0.9974279057100494,
#  0.9968227070535903,
#  0.9972160861802887,
#  0.9966108875238296,
#  0.9971858262474658,
#  0.9968529669864132,
#  0.9971555663146427,
#  0.9966108875238296,
#  0.9971555663146427]

# %%
most_accuracy = accuracy_rate.index(max(accuracy_rate)) + 1
most_accuracy
# Out:
# 9

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,7))
plt.plot(range(1,40),accuracy_rate,color = 'blue',marker = 'o', linestyle = ':', markerfacecolor = 'red', markersize = 8)
plt.title('Accuracy vs K vlaue')
plt.xlabel('K value')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# ERROR RATE TABLE

# %%
import numpy as np
error_rate = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(xtrain,ytrain)
    predict = knn.predict(xtest)
    error_rate.append(np.mean(predict != ytest))

# %%
error_rate
# Out:
# [np.float64(0.003600932005930947),
#  np.float64(0.005991466698943929),
#  np.float64(0.002511574424304778),
#  np.float64(0.003903531334160438),
#  np.float64(0.0019063757678457953),
#  np.float64(0.0034798922746391505),
#  np.float64(0.0019668956334916938),
#  np.float64(0.003207552879232608),
#  np.float64(0.0017853360365539988),
#  np.float64(0.0028141737525342694),
#  np.float64(0.0019366357006687445),
#  np.float64(0.003116773080763761),
#  np.float64(0.0019971555663146428),
#  np.float64(0.002693134021242473),
#  np.float64(0.0017853360365539988),
#  np.float64(0.002723393954065422),
#  np.float64(0.0019971555663146428),
#  np.float64(0.0028444336853572184),
#  np.float64(0.002027415499137592),
#  np.float64(0.002904953551003117),
#  np.float64(0.002239235028898236),
#  np.float64(0.002935213483826066),
#  np.float64(0.0023905346930129814),
#  np.float64(0.0028746936181801674),
#  np.float64(0.002481314491481829),
#  np.float64(0.002904953551003117),
# ...

# %%
min_error = error_rate.index(min(error_rate))+ 1
min_error
# Out:
# 9

# %%
plt.figure(figsize=(12,7))
plt.plot(range(1,40),error_rate,color = 'red', linestyle = '--', marker = 'o', markerfacecolor = 'blue', markersize = 8)
plt.title('Error vs K value')
plt.xlabel("K value")
plt.ylabel('Error rate')
# Out:
# Text(0, 0.5, 'Error rate')

# %%
model7 = KNeighborsClassifier(n_neighbors=9)
model7.fit(X_train,y_train)
model7.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
model7.score(X_test,y_test)
# Out:
# 0.688292431990801

# %% [markdown]
# ## Confusion Matrix(KNN)

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sn
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(model7.predict(X_test),y_test)
cm
# Out:
# array([[22151,  9135],
#        [ 1166,   595]])

# %%
sn.heatmap(cm, annot= True)
plt.xlabel('Predict')
plt.ylabel('Truth')
# Out:
# Text(50.722222222222214, 0.5, 'Truth')

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
model8 = GaussianNB()
model8.fit(X_train,y_train)
model8.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 1, 0])

# %%
model8.score(X_test,y_test)
# Out:
# 0.7036342179320362

# %% [markdown]
# ## XG_Boost

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier
model9 = XGBClassifier()
model9.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
model9.predict(X_test)
# Out:
# array([0, 0, 1, ..., 1, 1, 0])

# %%
model9.score(X_test,y_test)
# Out:
# 1.0
